# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID           City Country    Lat     Lng  Max Temp  Humidity  \
# 0        0     wloszczowa      PL  50.85   19.97     35.65        57
# 1        1     hambantota      LK   6.12   81.12     75.54       100
# 2        2        kirovsk      UA  48.64   38.64     25.97        95
# 3        3    boshnyakovo      RU  49.63  142.17     20.28        78
# 4        4  mount gambier      AU -37.83  140.77     66.11        77
#
#    Cloudiness  Wind Speed Current Description
# 0           0        6.22           clear sky
# 1          20        1.14          few clouds
# 2          35        4.65    scattered clouds
# 3         100        6.22     overcast clouds
# 4         100        6.91     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp_cri = float(input("Introduce the Minimum Temperature Criteria"))
max_temp_cri = float(input("Introduce the Maximum Temperature Criteria"))
# Out:
# Introduce the Minimum Temperature Criteria10
# Introduce the Maximum Temperature Criteria100

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp_cri) & \
                                       (city_data_df["Max Temp"] >= min_temp_cri)]

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                639
# City                   639
# Country                637
# Lat                    639
# Lng                    639
# Max Temp               639
# Humidity               639
# Cloudiness             639
# Wind Speed             639
# Current Description    639
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 0       wloszczowa      PL     35.65           clear sky  50.85   19.97
# 1       hambantota      LK     75.54          few clouds   6.12   81.12
# 2          kirovsk      UA     25.97    scattered clouds  48.64   38.64
# 3      boshnyakovo      RU     20.28     overcast clouds  49.63  142.17
# 4    mount gambier      AU     66.11     overcast clouds -37.83  140.77
# 5   guerrero negro      MX     60.15           clear sky  27.98 -114.06
# 7         ucluelet      CA     45.09          light rain  48.93 -125.55
# 8             yaan      NG     82.56           clear sky   7.38    8.57
# 9       banda aceh      ID     80.64     overcast clouds   5.56   95.32
# 11      shitanjing      CN     36.01     overcast clouds  39.23  106.34
#
#    Hotel Name
# 0
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 11

# %%
# 6a. Set parameters to search for hotels with 5000 meters.

params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# 6b. Iterate through the hotel DataFrame.
name = ''
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    params["location"]= f"{row['Lat']},{row['Lng']}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    # 6e. Make request and retrieve the JSON data from the search. 
    output = requests.get(base_url,params=params)
    if output.status_code == 200:
        print(f" {index} Processing {row['Lat']},{row['Lng']}")
    hotels =  output.json()   
    try:
        
        hotel_df.loc[index,"Hotel Name"] =  hotels['results'][0]['name']
        # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.    
    except IndexError:
        print(f"skipped ")
        hotel_df.loc[index,"Hotel Name"] =  np.nan
# Out:
#  0 Processing 50.85,19.97
#  1 Processing 6.12,81.12
#  2 Processing 48.64,38.64
# skipped
#  3 Processing 49.63,142.17
# skipped
#  4 Processing -37.83,140.77
#  5 Processing 27.98,-114.06
#  7 Processing 48.93,-125.55
#  8 Processing 7.38,8.57
# skipped
#  9 Processing 5.56,95.32
#  11 Processing 39.23,106.34
# skipped
#  12 Processing 29.45,55.68
#  13 Processing 35.5,134.23
#  14 Processing -30.18,-50.21
#  15 Processing 14.31,121.11
#  16 Processing 29.57,-104.42
#  17 Processing 9.52,-79.03
# skipped
#  18 Processing 46.73,-117.18
#  19 Processing 55.48,60.22
#  20 Processing 48.4,-89.32
#  21 Processing -38.65,-72.23
#  22 Processing 59.38,143.3
# skipped
#  23 Processing 54.08,-0.19
#  24 Processing -33.02,27.91
#  25 Processing 42.61,-5.62
#  26 Processing -0.12,-51.29
#  27 Processing 60.92,-46.05
#  28 Processing 45.02,-93.22
#  29 Processing -9.08,143.21
#  31 Processing -46.28,169.85
#  32 Processing 46.54,138.33
# skipped
#  33 Processing 69.77,21.02
#  34 Processing 52.79,-6.14
#  35 Processing 3.78,72.97
#  36 Processing 35.84,-90.7
#  37 Processing 57.41,-6.19
#  38 Processing 51.75,5.53
#  39 Processing 42.8,93.45
#  40 Processing 39.5,67.61
#  41 Processing 43.21,-75.46
#  42 Processing 7.77,-72.22
#  43 Processing 40.6,-124.16
#  44 Processing -35.72,150.18
#  45 Processing 41.96,42.96
#  46 Processing 61.67,96.37
# skipped
#  47 Processing -45.87,170.5
#  48 Processing 37.14,50.29
#  49 Processing 62.67,131.17
# skipped
#  50 Processing 39.15,-123.21
#  51 Processing -8.93,125.41
# skipped
#  52 Processing 38.42,-108.27
# skipped
#  53 Processing 64.86,11.24
#  55 Processing 52.54,62.49
#  56 Processing 22.57,59.53
#  57 Processing 33.98,51.44
#  58 Processing -25.24,130.99
#  59 Processing -3.67,152.43
#  61 Processing 45.76,106.27
#  62 Processing -5.26,-36.72
#  63 Processing -21.48,-56.14
#  64 Processing 53.28,80.77
#  65 Processing 22.08,-159.32
#  66 Processing 4.88,-1.76
#  67 Processing -10.45,161.92
#  68 Processing -3.84,-62.06
#  69 Processing 45.44,40.58
#  70 Processing 38.72,69.71
#  71 Processing 64.84,-147.72
#  72 Processing -22.97,-42.03
#  73 Processing -30.74,30.45
#  74 Processing -5.09,-81.11
#  75 Processing 64.25,-15.21
#  76 Processing 53.94,139.92
#  77 Processing 36.29,-76.25
#  78 Processing -13.73,15.07
# skipped
#  79 Processing 4.42,-7.35
#  80 Processing 68.12,13.5
#  81 Processing 18.21,-71.1
#  82 Processing -10.67,-77.83
#  83 Processing 18.22,-63.06
#  84 Processing 41.35,-1.64
#  85 Processing 57.79,-152.41
#  86 Processing 66.08,13.82
#  87 Processing 66.83,70.83
#  88 Processing 41.19,40.99
#  89 Processing -8.38,-74.55
#  90 Processing -29.95,-71.34
#  91 Processing 70.86,29.09
#  92 Processing 7.53,-12.51
#  93 Processing 71.04,27.85
#  94 Processing -13.85,136.42
#  95 Processing 28.66,-17.92
#  96 Processing 49.49,105.92
#  98 Processing 62.46,-114.35
#  99 Processing 4.38,-7.72
#  100 Processing 28.37,129.48
#  101 Processing 54.67,20.13
#  102 Processing 39.28,-80.34
#  103 Processing 31.46,131.23
#  104 Processing -12.02,17.48
# skipped
#  105 Processing -31.95,141.43
#  106 Processing 66.08,33.04
#  107 Processing 43.06,44.74
#  108 Processing 36.54,61.16
#  109 Processing 5.41,100.34
#  110 Processing -28.77,114.6
#  111 Processing 50.12,-5.54
#  112 Processing 68.56,14.91
#  113 Processing 36.32,139.2
#  114 Processing 45.72,40.72
# skipped
#  115 Processing 59.7,150.17
# skipped
#  116 Processing 56.45,138.17
#  117 Processing 11.0,122.67
#  118 Processing 18.44,1.41
# skipped
#  119 Processing 27.62,110.1
# skipped
#  120 Processing -0.22,20.87
# skipped
#  121 Processing 63.9,122.76
# skipped
#  122 Processing 26.65,74.03
#  123 Processing 16.33,-15.0
# skipped
#  124 Processing -42.88,147.33
#  125 Processing 41.14,-73.36
#  126 Processing 20.87,-90.4
#  127 Processing 61.36,63.58
#  128 Processing 37.68,-113.06
#  129 Processing 47.83,36.13
# skipped
#  130 Processing 16.15,36.2
# skipped
#  131 Processing 36.75,3.04
#  132 Processing 63.44,-20.27
#  133 Processing 36.68,-121.66
#  134 Processing 4.14,96.13
#  135 Processing 35.13,140.3
#  136 Processing -41.41,175.52
#  137 Processing 20.22,-87.47
#  138 Processing -26.79,-60.44
#  139 Processing -5.17,32.35
# skipped
#  141 Processing -25.17,45.05
# skipped
#  142 Processing 38.89,-76.51
#  143 Processing -16.48,-151.75
#  144 Processing -21.15,149.2
#  146 Processing 45.36,36.48
#  147 Processing 61.69,33.62
#  148 Processing 5.62,-54.4
#  149 Processing 34.62,-79.01
#  150 Processing 42.12,118.78
#  151 Processing 27.67,-105.17
#  152 Processing 65.99,57.53
#  153 Processing 2.15,21.52
#  154 Processing 36.73,-108.22
#  155 Processing 0.56,31.39
#  156 Processing 58.36,82.83
# skipped
#  157 Processing 64.89,-23.71
#  158 Processing 60.82,-115.8
#  159 Processing 14.2,24.67
#  160 Processing 43.61,-116.39
#  161 Processing -2.02,147.27
#  163 Processing 54.72,-113.29
#  164 Processing -24.79,-50.01
#  165 Processing 15.85,-97.07
#  166 Processing 39.18,-84.53
#  167 Processing -37.88,147.98
#  168 Processing 8.25,34.58
#  169 Processing 51.03,-4.22
#  170 Processing 18.39,42.45
#  171 Processing 27.75,-107.63
#  172 Processing 44.83,0.5
#  173 Processing 15.26,100.34
#  174 Processing 46.57,32.15
#  175 Processing -38.0,-57.56
#  176 Processing -23.7,133.88
#  177 Processing 60.26,37.98
#  178 Processing 25.52,90.22
#  179 Processing 46.19,-123.83
#  180 Processing -16.77,31.58
# skipped
#  181 Processing 42.6,-73.97
# skipped
#  182 Processing -17.73,-149.15
#  183 Processing -9.11,124.89
#  184 Processing 14.88,103.49
#  185 Processing 60.37,93.04
#  186 Processing 45.85,123.3
# skipped
#  187 Processing 54.52,30.41
#  188 Processing 20.52,-13.05
#  189 Processing -34.58,150.86
#  190 Processing 70.37,31.11
#  191 Processing 19.11,37.33
#  192 Processing 53.83,-101.25
#  193 Processing -23.32,-46.22
#  194 Processing 41.76,86.15
#  195 Processing -17.71,-39.25
#  196 Processing -9.88,-56.09
#  197 Processing -9.66,120.26
#  198 Processing 46.38,-82.63
#  199 Processing 9.49,50.81
#  200 Processing 6.87,81.35
#  202 Processing 53.6,91.39
#  203 Processing -28.0,153.43
#  204 Processing 33.85,-118.05
#  205 Processing -5.2,-35.46
#  206 Processing 22.29,114.16
#  207 Processing -33.87,121.9
#  208 Processing -12.19,-43.22
#  209 Processing 55.74,-97.86
#  210 Processing 57.84,108.35
# skipped
#  211 Processing -34.48,-54.33
#  212 Processing 25.02,37.27
#  213 Processing -21.36,55.77
#  214 Processing -41.87,-73.82
#  215 Processing 43.13,133.13
#  216 Processing -3.77,-61.64
#  217 Processing 45.39,47.37
#  218 Processing 39.45,-86.18
#  219 Processing 24.68,116.14
#  220 Processing 34.78,72.36
#  221 Processing 61.03,42.49
# skipped
#  222 Processing 8.47,-0.01
#  224 Processing 42.25,-75.83
#  225 Processing -34.05,23.37
#  226 Processing 55.1,-105.28
#  227 Processing 60.14,-45.24
#  228 Processing 44.83,-87.38
#  230 Processing 14.3,-91.92
#  231 Processing 43.78,19.3
#  232 Processing 40.22,116.22
#  233 Processing 50.72,136.63
#  234 Processing 40.16,-8.33
#  235 Processing -37.62,-73.65
#  236 Processing 35.51,27.21
#  237 Processing -7.95,110.28
#  238 Processing -19.06,-169.92
#  239 Processing 40.8,-124.16
#  240 Processing -34.42,19.23
#  241 Processing 30.41,-89.04
#  242 Processing -33.7,-53.46
#  243 Processing 58.34,44.76
#  244 Processing -16.7,-151.02
#  245 Processing -34.76,-56.39
#  246 Processing 39.5,106.71
#  247 Processing 15.74,-96.47
#  248 Processing 57.05,-135.33
#  249 Processing 21.35,-158.09
#  250 Processing -13.87,-171.6
#  251 Processing 39.36,-9.38
#  253 Processing -20.23,164.02
# skipped
#  254 Processing 3.82,117.25
# skipped
#  255 Processing -16.41,-67.53
#  256 Processing -20.52,57.52
#  257 Processing 22.68,-3.98
# skipped
#  258 Processing 53.9,27.57
#  259 Processing -30.89,-55.53
#  260 Processing 21.32,-158.01
#  261 Processing -45.42,167.72
#  262 Processing 29.29,-81.06
#  263 Processing 60.4,-1.35
#  264 Processing 56.25,22.75
#  265 Processing 57.8,158.67
#  266 Processing 45.52,-74.65
#  267 Processing 26.59,12.78
#  268 Processing 37.1,-113.58
#  269 Processing 24.7,-77.77
#  270 Processing 19.95,-97.27
#  272 Processing -23.86,35.38
#  273 Processing -26.62,-54.13
#  274 Processing 51.38,1.39
#  275 Processing -31.59,28.78
#  276 Processing 55.75,38.85
#  277 Processing 29.58,80.22
#  278 Processing 63.05,179.32
# skipped
#  280 Processing 45.41,141.67
#  281 Processing 61.24,7.7
#  282 Processing 57.79,43.19
#  283 Processing 64.5,-165.41
#  284 Processing 66.04,-17.34
#  285 Processing 50.68,156.12
#  286 Processing 46.43,26.4
#  287 Processing -20.44,-53.76
#  288 Processing 48.92,40.4
#  289 Processing -1.2,-46.02
#  291 Processing -25.4,-70.48
#  292 Processing -0.41,-65.02
#  293 Processing 39.51,54.37
#  294 Processing 64.86,-147.8
#  295 Processing 53.7,54.26
#  296 Processing 32.3,-9.24
#  297 Processing 10.93,108.1
#  298 Processing -9.09,-78.58
#  299 Processing -4.35,152.26
#  300 Processing 42.25,-2.5
#  301 Processing -13.2,49.05
#  302 Processing 11.78,-72.44
#  303 Processing 29.11,21.29
#  304 Processing 28.02,-97.52
#  305 Processing 3.81,43.25
#  306 Processing 24.83,-104.83
# skipped
#  307 Processing -25.43,31.95
#  308 Processing 37.12,-93.48
#  309 Processing 53.52,-2.49
#  310 Processing -23.72,44.38
#  311 Processing -46.6,168.33
#  312 Processing 58.52,125.52
# skipped
#  313 Processing 48.42,-2.25
#  314 Processing -21.3,47.63
# skipped
#  315 Processing -21.25,-48.32
#  316 Processing -8.01,-34.86
#  317 Processing 59.12,11.39
#  319 Processing 32.35,-85.2
#  320 Processing 29.03,21.55
#  321 Processing -34.93,138.6
#  322 Processing -13.13,39.0
#  323 Processing 34.67,138.95
#  324 Processing -23.66,27.74
#  325 Processing -38.37,-60.28
#  326 Processing 62.58,6.13
#  328 Processing -21.2,-175.2
#  329 Processing 18.73,-103.68
#  330 Processing 44.51,50.26
#  331 Processing -46.19,168.86
#  332 Processing -15.77,128.73
#  333 Processing 5.97,-1.78
#  334 Processing 41.37,-73.41
#  335 Processing 29.97,40.21
#  336 Processing 35.98,-114.83
#  337 Processing -11.38,43.28
#  338 Processing 40.54,-7.27
#  339 Processing 31.72,-116.57
#  340 Processing 21.46,-71.14
#  341 Processing 35.08,109.09
#  342 Processing -5.56,-80.82
#  343 Processing 40.0,30.17
#  344 Processing 12.53,-13.13
# skipped
#  345 Processing 78.22,15.64
#  346 Processing 43.65,111.98
#  347 Processing 8.0,124.29
#  348 Processing 6.97,37.87
#  349 Processing 62.23,-6.59
#  351 Processing -16.17,49.77
#  352 Processing 35.73,140.83
#  353 Processing 63.64,54.86
#  354 Processing -6.84,-79.93
#  356 Processing -33.59,26.89
#  357 Processing -30.16,-53.57
#  359 Processing -53.15,-70.92
#  360 Processing -20.33,-40.29
#  362 Processing 2.04,45.34
#  363 Processing 4.41,114.01
#  364 Processing 13.07,-59.53
#  365 Processing -6.22,155.63
#  366 Processing 27.09,67.73
#  367 Processing -20.41,57.7
#  368 Processing 25.21,64.64
#  369 Processing 25.29,51.53
#  370 Processing 13.48,-88.18
#  371 Processing -24.87,113.63
#  372 Processing -23.85,151.25
#  373 Processing -2.89,-40.12
#  374 Processing 22.31,89.79
#  376 Processing -20.1,146.27
#  377 Processing -0.72,8.78
#  378 Processing 25.92,-109.18
#  379 Processing 11.24,-74.2
#  380 Processing 55.28,-114.77
#  381 Processing 8.41,48.48
#  383 Processing 49.25,-123.12
#  384 Processing 48.8,-79.2
#  385 Processing 37.46,-122.43
#  386 Processing 48.85,-54.01
# skipped
#  387 Processing 58.52,-117.14
#  388 Processing 62.16,-7.17
#  389 Processing 60.34,102.28
# skipped
#  390 Processing -28.78,32.04
#  391 Processing 68.05,39.51
# skipped
#  392 Processing 65.7,82.47
#  393 Processing 42.16,-72.33
#  395 Processing 51.23,-58.65
# skipped
#  396 Processing -38.07,174.82
#  398 Processing -0.74,-90.35
#  399 Processing -9.01,-35.22
#  400 Processing -20.74,116.85
#  401 Processing 48.57,83.65
#  402 Processing 56.67,96.06
#  403 Processing -23.12,-134.97
#  404 Processing 30.78,-110.87
#  405 Processing 56.45,36.57
#  406 Processing 1.24,111.46
#  407 Processing -27.43,29.17
#  408 Processing -21.64,-41.05
#  409 Processing 19.73,-155.09
#  410 Processing 50.7,-127.42
#  411 Processing 55.36,78.36
#  412 Processing -6.13,12.37
#  414 Processing 31.8,-106.2
#  415 Processing 31.28,49.6
#  416 Processing 26.85,89.39
#  417 Processing 58.81,-122.7
#  418 Processing 15.32,121.37
#  420 Processing -19.93,-60.77
# skipped
#  421 Processing 61.84,6.81
#  422 Processing -11.7,43.26
#  423 Processing 40.28,97.2
# skipped
#  424 Processing -19.9,48.8
#  425 Processing -4.38,-79.95
#  427 Processing -7.61,-72.9
#  428 Processing 59.37,28.61
#  429 Processing 18.74,7.39
#  430 Processing -7.75,-34.83
#  431 Processing 25.53,-103.25
#  432 Processing -4.88,-66.9
#  433 Processing 59.63,112.74
#  434 Processing -33.93,18.42
#  435 Processing 4.93,-52.33
#  436 Processing 62.0,132.43
#  437 Processing 24.34,124.16
#  438 Processing -41.29,174.78
#  439 Processing 46.38,-75.97
#  440 Processing 1.74,98.78
#  441 Processing 6.04,80.22
#  442 Processing -27.27,28.48
#  443 Processing -28.24,-48.67
#  444 Processing 33.73,135.98
#  445 Processing -23.67,-46.46
#  446 Processing 35.99,-106.08
#  448 Processing 33.08,-16.33
#  449 Processing 61.38,152.75
# skipped
#  450 Processing -0.6,73.08
#  451 Processing 16.58,98.83
#  452 Processing 38.52,-28.7
#  453 Processing 43.65,51.2
#  454 Processing 27.26,33.81
#  455 Processing 62.86,42.71
#  456 Processing -27.8,-64.26
#  457 Processing -5.22,145.8
#  458 Processing -0.19,-74.78
#  459 Processing 59.37,24.93
#  460 Processing 62.53,155.8
# skipped
#  461 Processing 26.62,-78.28
#  462 Processing -31.54,-68.54
#  463 Processing 42.53,-1.67
#  464 Processing 60.1,19.93
#  465 Processing -41.07,145.92
#  466 Processing -37.2,175.87
#  467 Processing 35.17,-2.93
#  468 Processing 16.86,-99.89
#  469 Processing -19.55,169.27
#  470 Processing 36.62,-121.92
#  471 Processing 47.33,-79.43
#  472 Processing 24.96,118.38
#  474 Processing 37.73,-25.67
#  476 Processing 9.32,41.45
#  477 Processing 28.97,50.84
#  478 Processing 28.65,70.66
#  480 Processing -0.87,134.08
#  481 Processing 40.83,-74.53
#  482 Processing -0.95,122.79
#  483 Processing -0.95,100.35
#  484 Processing -8.19,114.97
#  485 Processing -21.21,-159.78
#  487 Processing -35.33,-72.42
#  488 Processing 17.49,44.13
#  489 Processing 35.01,37.05
#  490 Processing 38.42,-121.42
#  491 Processing 7.42,81.82
#  492 Processing 31.21,16.59
#  493 Processing 59.06,80.86
#  494 Processing 33.99,50.68
#  495 Processing 28.07,95.33
#  496 Processing 25.58,83.57
#  497 Processing -35.57,138.62
#  498 Processing 58.45,92.17
#  499 Processing 34.73,-120.03
#  500 Processing 50.13,-101.67
#  501 Processing 46.48,134.26
#  502 Processing -9.8,-139.03
#  503 Processing 35.3,37.18
# skipped
#  504 Processing 49.42,130.08
#  505 Processing 34.02,-84.36
#  506 Processing 24.02,92.9
#  507 Processing 68.75,161.3
#  508 Processing 34.98,139.87
#  509 Processing 22.89,-109.91
#  510 Processing -34.65,-58.62
#  511 Processing 28.17,94.77
#  512 Processing 5.38,-52.95
#  513 Processing 64.75,20.95
#  514 Processing 29.5,78.75
#  516 Processing 42.03,-8.16
#  518 Processing -35.35,150.47
#  519 Processing 60.75,-137.51
#  520 Processing -23.3,30.72
#  521 Processing 10.57,72.64
#  522 Processing 27.92,-15.57
#  523 Processing -20.34,57.76
#  524 Processing 52.06,-2.71
#  525 Processing -35.62,174.5
#  526 Processing 64.38,-173.3
# skipped
#  527 Processing 50.93,21.39
#  528 Processing -34.53,20.04
#  529 Processing 24.09,32.91
#  530 Processing 43.8,87.6
#  531 Processing 40.8,-81.52
#  533 Processing 41.87,72.94
#  534 Processing 13.64,16.49
#  535 Processing -19.84,34.84
#  536 Processing 35.85,71.79
#  537 Processing 8.28,-7.68
#  538 Processing 50.95,5.11
#  540 Processing 18.93,84.6
#  541 Processing 37.72,-25.43
#  542 Processing 38.42,77.24
#  544 Processing 8.6,77.95
#  545 Processing 20.93,-17.03
#  546 Processing -14.97,22.68
#  547 Processing 44.81,-91.5
#  549 Processing -28.87,153.57
#  550 Processing -38.27,141.97
#  551 Processing 37.57,126.98
#  552 Processing -14.27,50.17
#  553 Processing -6.98,-34.83
#  554 Processing 39.82,-7.49
#  555 Processing -7.94,110.25
#  556 Processing 45.62,-61.35
#  557 Processing 47.67,-52.73
#  558 Processing -6.72,32.07
#  559 Processing 41.72,-8.86
#  560 Processing -45.58,-72.07
#  561 Processing -19.8,-45.69
#  563 Processing 51.26,-80.61
#  564 Processing -28.65,153.62
#  565 Processing 40.43,71.72
#  566 Processing -2.67,141.3
#  567 Processing 59.7,30.79
#  568 Processing -3.8,102.27
#  569 Processing 5.66,-53.78
#  570 Processing 40.12,116.65
#  571 Processing 54.77,-101.86
#  572 Processing 34.17,77.58
#  573 Processing -38.55,-58.74
#  574 Processing -34.0,24.73
#  575 Processing -14.78,24.8
#  576 Processing -8.65,115.22
#  577 Processing 47.18,8.46
#  578 Processing 5.35,48.53
#  579 Processing 61.28,108.01
# skipped
#  580 Processing 21.12,70.12
#  581 Processing 13.22,-59.52
#  582 Processing 11.03,-63.86
#  583 Processing -19.03,-65.26
#  584 Processing 46.7,-75.45
#  585 Processing -43.3,-65.1
#  586 Processing 48.43,29.54
# skipped
#  587 Processing -13.7,-76.22
#  588 Processing 44.26,135.11
#  590 Processing 29.58,-9.5
# skipped
#  591 Processing -33.65,115.33
#  592 Processing 39.05,-27.98
#  593 Processing 36.57,-119.61
#  594 Processing 39.79,37.0
#  595 Processing -8.77,160.7
#  596 Processing 43.17,-79.48
#  597 Processing 37.15,122.38
#  598 Processing 31.77,-107.62
#  599 Processing 43.12,6.12
#  600 Processing 50.08,132.17
# skipped
#  601 Processing -8.14,159.59
#  602 Processing 15.17,44.32
#  603 Processing -32.32,-58.08
#  604 Processing -17.88,36.89
#  605 Processing -16.92,145.77
#  606 Processing -46.13,167.68
#  607 Processing 34.64,-120.46
#  608 Processing -40.81,-63.0
#  609 Processing 43.52,-8.15
#  610 Processing 17.96,-102.2
#  611 Processing 52.14,113.5
#  612 Processing 62.6,29.76
#  613 Processing -35.17,173.17
#  614 Processing 53.25,140.18
# skipped
#  615 Processing 52.61,1.73
#  616 Processing 37.8,-25.58
#  617 Processing 27.9,102.26
#  618 Processing 63.76,121.62
#  619 Processing -1.57,9.26
#  620 Processing -42.78,147.06
#  621 Processing 57.93,12.53
#  622 Processing -31.73,-60.52
#  623 Processing -5.82,13.45
#  625 Processing -2.53,112.95
#  626 Processing 60.73,77.59
#  627 Processing 1.2,-70.17
# skipped
#  628 Processing -0.13,-67.09
#  629 Processing 54.48,53.47
#  630 Processing 14.9,-24.5
#  631 Processing 65.44,52.15
#  633 Processing 18.8,110.4
#  634 Processing 30.06,31.25
#  635 Processing 34.42,-79.37
#  636 Processing 64.54,-21.92
#  637 Processing 32.12,20.07
#  638 Processing -23.99,-46.26
#  639 Processing 13.64,4.03
#  641 Processing 24.47,54.37
#  642 Processing 14.35,108.0
#  643 Processing 44.83,-106.92
#  644 Processing 20.89,-156.47
#  645 Processing 69.65,18.96
#  646 Processing -5.12,120.25
#  647 Processing 20.77,78.17
#  649 Processing -6.88,112.21
#  651 Processing 62.27,21.38
#  652 Processing 51.55,8.57
#  653 Processing 17.02,54.09
#  654 Processing -11.1,-77.61
#  656 Processing 66.71,27.43
#  657 Processing 60.55,-151.26
#  658 Processing 53.57,52.8
# skipped
#  659 Processing 24.25,86.65
#  660 Processing 50.41,80.23
#  661 Processing 58.42,94.67
#  662 Processing 63.84,-22.43
#  663 Processing -15.86,-38.88
#  664 Processing 36.62,101.77
#  665 Processing 27.2,60.68
#  666 Processing 51.32,42.77
# skipped
#  667 Processing 26.35,127.87
#  668 Processing -54.8,-68.3
#  669 Processing 47.38,-61.86
#  670 Processing 55.34,-131.65
#  671 Processing 26.18,127.76
#  672 Processing -8.73,35.28
#  673 Processing 39.46,-3.61
#  674 Processing -2.57,150.8
#  675 Processing -33.92,25.57
#  676 Processing 7.71,81.69
#  677 Processing 32.67,-17.1
#  678 Processing 4.75,115.0
#  680 Processing 55.1,80.96
#  681 Processing 70.03,20.97
#  682 Processing 3.07,172.79
#  683 Processing 13.93,41.69
# skipped
#  684 Processing 42.1,-79.24
#  685 Processing -41.45,147.17

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.count()
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                City Country  Max Temp Current Description    Lat     Lng  \
# 0        wloszczowa      PL     35.65           clear sky  50.85   19.97
# 1        hambantota      LK     75.54          few clouds   6.12   81.12
# 4     mount gambier      AU     66.11     overcast clouds -37.83  140.77
# 5    guerrero negro      MX     60.15           clear sky  27.98 -114.06
# 7          ucluelet      CA     45.09          light rain  48.93 -125.55
# ..              ...     ...       ...                 ...    ...     ...
# 680          chulym      RU     11.03     overcast clouds  55.10   80.96
# 681        skjervoy      NO     41.61     overcast clouds  70.03   20.97
# 682      butaritari      KI     81.21          light rain   3.07  172.79
# 684       jamestown      US     42.03           clear sky  42.10  -79.24
# 685      launceston      AU     69.44     overcast clouds -41.45  147.17
#
#                             Hotel Name
# 0                        Hotel Mariage
# 1                          Bungalow 63
# 4                        The Commodore
# 5         Casa Laguna, Bed & Breakfast
# 7         Black Rock Oceanfront Resort
# ..                                 ...
# 680                       "U Tat'yany"
# 681              Skjervøy fiskecamp AS
# 682                 Isles Sunset Lodge
# 684     Hampton Inn & Suites Jamestown
# 685  Hotel Grand Chancellor Launceston
#
# [580 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather </dt><dd>{Current Description} and {Max Temp} °F</dd>

</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
