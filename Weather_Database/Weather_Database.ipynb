# %% [markdown]
# # Module 6 Challenge

# %%
# Imports

import pandas as pd
import requests
import numpy as np
import random
from citipy import citipy
from config import g_key
from config import weather_api_key
import time

# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data (25 points)

# %% [markdown]
# Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.

# %% [markdown]
# ### Created a new set of 2,000 random latitudes and longitudes.

# %%
# function to generate Coordinates
def genCoordinates(amount):
    lats = []
    lngs = []
    for i in range(0,amount):
        lats.append(random.randint(-90,90)+random.random())
        lngs.append(random.randint(-180,180)+random.random())
    coordinates = list(zip(lats,lngs))    
    return coordinates

# %% [markdown]
# ### Get the nearest city using the citipy module.

# %%
# function to extract the city names from citipy using 
# the coordinates previously generated
def getCitiesNames(coordinates):
    cities = set()
    for coordinate in coordinates:
        city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
        cities.add(city) 
    return cities

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap.

# %%
# Example call 
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&appid='+weather_api_key
city = 'Narsaq'
city_url = base_url + '&q='+city
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -46.05, 'lat': 60.9167},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 10.62,
#   'feels_like': -0.74,
#   'temp_min': 10.62,
#   'temp_max': 10.62,
#   'pressure': 1018,
#   'humidity': 77,
#   'sea_level': 1018,
#   'grnd_level': 1015},
#  'visibility': 10000,
#  'wind': {'speed': 7.49, 'deg': 31, 'gust': 7},
#  'clouds': {'all': 1},
#  'dt': 1647824657,
#  'sys': {'type': 1,
#   'id': 47,
#   'country': 'GL',
#   'sunrise': 1647767146,
#   'sunset': 1647811054},
#  'timezone': -10800,
#  'id': 3421719,
#  'name': 'Narsaq',
#  'cod': 200}

# %%
Latitude = round(city_weather['coord']['lat'],2)
Longitude = round(city_weather['coord']['lon'],2)
Maximum_temperature = city_weather['main']['temp_max']
Percent_humidity = city_weather['main']['humidity']
Percent_cloudiness = city_weather['clouds']['all']
Wind_speed = city_weather['wind']['speed']
Weather_description = city_weather['weather'][0]['description']
print(f" Latitude {Latitude}, Longitude {Longitude}")  
print(f" Maximum_temperature {Maximum_temperature} ")
print(f" Percent_humidity {Percent_humidity}, Percent_cloudiness {Percent_cloudiness}")
print(f"  Wind_speed {Wind_speed} Weather_description {Weather_description}")
# Out:
#  Latitude 60.92, Longitude -46.05
#  Maximum_temperature 10.62
#  Percent_humidity 77, Percent_cloudiness 1
#   Wind_speed 7.49 Weather_description clear sky

# %% [markdown]
# ### Retrieve the following information from the API call:
#
# * Latitude and longitude
# * Maximum temperature
# * Percent humidity
# * Percent cloudiness
# * Wind speed
# * Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# function to retrieve the weather information of the cities
def retrieveDataFromAPI(base_url,parameters):
    
    ctt = 1
    stt = 1
    coordinates = genCoordinates(2000)
    cities = getCitiesNames(coordinates)
    cities_weather = []
    print('Beginning Data Retrieval')
    print('--------------------------------------')
    cities_weather = []
    for city_name in cities:
        print(f'Processing Record {ctt} of Set {stt}  | {city_name}')
        if ctt == 50:
            time.sleep(40)
            stt +=1
            ctt = 1

        parameters['q'] = city_name

        city_weather = requests.get(base_url, parameters)
        if city_weather.status_code == 200:
            cities_weather.append(formatJson(city_weather.json(),city_name))
        ctt+=1

    return cities_weather

# %%
def formatJson(city_weather,city_name):
    city_data = None
    try: 
        city_country = city_weather["sys"]["country"]
        city_lat = round(city_weather['coord']['lat'],2)
        city_lng = round(city_weather['coord']['lon'],2)
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']

        city_data={"City": city_name,
                   "Country": city_country,
                   "Lat": city_lat,
                   "Lng": city_lng,
                   "Max Temp": city_max_temp,
                   "Humidity": city_humidity,
                   "Cloudiness": city_clouds,
                   "Wind Speed": city_wind,
                   "Current Description": city_desc}
        #print(city_data.items())
    except Exception as inst:
        print(f'Not able to process city {city_name}')
        pass
    return city_data

# %% [markdown]
# ### Add the data to a new DataFrame.
#
# * Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:

# %%
# function to create a frame with all the
# information of the weather of the cities
def createDataFrame(cities):
    weather_df = pd.DataFrame(cities)
    return weather_df

# %%
base_url = 'http://api.openweathermap.org/data/2.5/weather'
parameters = {
    'units' : 'imperial',
    'appid' : weather_api_key
}

cities = retrieveDataFromAPI(base_url,parameters)
df = createDataFrame(cities)
df.head()
# Out:
# Beginning Data Retrieval
# --------------------------------------
# Processing Record 1 of Set 1  | wloszczowa
# Processing Record 2 of Set 1  | hambantota
# Processing Record 3 of Set 1  | kirovsk
# Processing Record 4 of Set 1  | boshnyakovo
# Processing Record 5 of Set 1  | mount gambier
# Processing Record 6 of Set 1  | guerrero negro
# Processing Record 7 of Set 1  | talnakh
# Processing Record 8 of Set 1  | ucluelet
# Processing Record 9 of Set 1  | yaan
# Processing Record 10 of Set 1  | banda aceh
# Processing Record 11 of Set 1  | toora-khem
# Processing Record 12 of Set 1  | shitanjing
# Processing Record 13 of Set 1  | sirjan
# Processing Record 14 of Set 1  | tottori
# Processing Record 15 of Set 1  | cidreira
# Processing Record 16 of Set 1  | santa rosa
# Processing Record 17 of Set 1  | ojinaga
# Processing Record 18 of Set 1  | tubuala
# Processing Record 19 of Set 1  | pullman
# Processing Record 20 of Set 1  | karabash
# Processing Record 21 of Set 1  | thunder bay
# Processing Record 22 of Set 1  | karmana
# Processing Record 23 of Set 1  | vilcun
# Processing Record 24 of Set 1  | okhotsk
# Processing Record 25 of Set 1  | bridlington
# Processing Record 26 of Set 1  | east london
# Processing Record 27 of Set 1  | san andres del rabanedo
# Processing Record 28 of Set 1  | mazagao
# Processing Record 29 of Set 1  | narsaq
# Processing Record 30 of Set 1  | saint anthony
# Processing Record 31 of Set 1  | daru
# Processing Record 32 of Set 1  | egvekinot
# Processing Record 33 of Set 1  | kaitangata
# Processing Record 34 of Set 1  | svetlaya
# Processing Record 35 of Set 1  | samusu
# Processing Record 36 of Set 1  | storslett
# Processing Record 37 of Set 1  | arklow
# Processing Record 38 of Set 1  | mahibadhoo
# Processing Record 39 of Set 1  | jonesboro
# Processing Record 40 of Set 1  | portree
# Processing Record 41 of Set 1  | oss
# Processing Record 42 of Set 1  | hami
# Processing Record 43 of Set 1  | panjakent
# Processing Record 44 of Set 1  | roma
# Processing Record 45 of Set 1  | san cristobal
# Processing Record 46 of Set 1  | fortuna
# Processing Record 47 of Set 1  | batemans bay
# Processing Record 48 of Set 1  | khani
# Processing Record 49 of Set 1  | baykit
# Processing Record 50 of Set 1  | dunedin
# Processing Record 2 of Set 2  | rudsar
# Processing Record 3 of Set 2  | borogontsy
# Processing Record 4 of Set 2  | ukiah
# Processing Record 5 of Set 2  | airai
# Processing Record 6 of Set 2  | montrose
# Processing Record 7 of Set 2  | rorvik
# Processing Record 8 of Set 2  | tiksi
# Processing Record 9 of Set 2  | lisakovsk
# Processing Record 10 of Set 2  | sur
# Processing Record 11 of Set 2  | kashan
# Processing Record 12 of Set 2  | yulara
# Processing Record 13 of Set 2  | namatanai
# Processing Record 14 of Set 2  | anadyr
# Processing Record 15 of Set 2  | mandalgovi
# Processing Record 16 of Set 2  | mys shmidta
# Processing Record 17 of Set 2  | senmonorom
# Processing Record 18 of Set 2  | pendencias
# Processing Record 19 of Set 2  | jardim
# Processing Record 20 of Set 2  | bayevo
# Processing Record 21 of Set 2  | kapaa
# Processing Record 22 of Set 2  | takoradi
# Processing Record 23 of Set 2  | kirakira
# Processing Record 24 of Set 2  | codajas
# Processing Record 25 of Set 2  | kropotkin
# Processing Record 26 of Set 2  | obigarm
# Processing Record 27 of Set 2  | fairbanks
# Processing Record 28 of Set 2  | arraial do cabo
# Processing Record 29 of Set 2  | port shepstone
# Processing Record 30 of Set 2  | paita
# Processing Record 31 of Set 2  | hofn
# Processing Record 32 of Set 2  | mnogovershinnyy
# Processing Record 33 of Set 2  | elizabeth city
# Processing Record 34 of Set 2  | caconda
# Processing Record 35 of Set 2  | tabou
# Processing Record 36 of Set 2  | gravdal
# Processing Record 37 of Set 2  | barahona
# Processing Record 38 of Set 2  | paramonga
# Processing Record 39 of Set 2  | the valley
# Processing Record 40 of Set 2  | calatayud
# Processing Record 41 of Set 2  | kodiak
# Processing Record 42 of Set 2  | korgen
# Processing Record 43 of Set 2  | yar-sale
# Processing Record 44 of Set 2  | ardesen
# Processing Record 45 of Set 2  | pucallpa
# Processing Record 46 of Set 2  | coquimbo
# Processing Record 47 of Set 2  | berlevag
# Processing Record 48 of Set 2  | bonthe
# Processing Record 49 of Set 2  | othonoi
# Processing Record 50 of Set 2  | alotau
# Processing Record 2 of Set 3  | mehamn
# Processing Record 3 of Set 3  | alyangula
# Processing Record 4 of Set 3  | los llanos de aridane
# Processing Record 5 of Set 3  | cockburn harbour
# Processing Record 6 of Set 3  | darhan
# Processing Record 7 of Set 3  | novyy urengoy
# Processing Record 8 of Set 3  | yellowknife
# Processing Record 9 of Set 3  | harper
# Processing Record 10 of Set 3  | naze
# Processing Record 11 of Set 3  | svetlyy
# Processing Record 12 of Set 3  | clarksburg
# Processing Record 13 of Set 3  | buariki
# Processing Record 14 of Set 3  | kushima
# Processing Record 15 of Set 3  | camacupa
# Processing Record 16 of Set 3  | broken hill
# Processing Record 17 of Set 3  | loukhi
# Processing Record 18 of Set 3  | oktyabrskoye
# Processing Record 19 of Set 3  | sarakhs
# Processing Record 20 of Set 3  | georgetown
# Processing Record 21 of Set 3  | geraldton
# Processing Record 22 of Set 3  | penzance
# Processing Record 23 of Set 3  | stokmarknes
# Processing Record 24 of Set 3  | isesaki
# Processing Record 25 of Set 3  | ilinskaya
# Processing Record 26 of Set 3  | arman
# Processing Record 27 of Set 3  | ayan
# Processing Record 28 of Set 3  | dingle
# Processing Record 29 of Set 3  | kidal
# Processing Record 30 of Set 3  | luyang
# Processing Record 31 of Set 3  | boende
# Processing Record 32 of Set 3  | kysyl-syr
# Processing Record 33 of Set 3  | merta
# Processing Record 34 of Set 3  | saint-louis
# Processing Record 35 of Set 3  | hobart
# Processing Record 36 of Set 3  | westport
# Processing Record 37 of Set 3  | saleaula
# Processing Record 38 of Set 3  | celestun
# Processing Record 39 of Set 3  | sovetskiy
# Processing Record 40 of Set 3  | cedar city
# Processing Record 41 of Set 3  | ternuvate
# Processing Record 42 of Set 3  | wagar
# Processing Record 43 of Set 3  | algiers
# Processing Record 44 of Set 3  | vestmannaeyjar
# Processing Record 45 of Set 3  | salinas
# Processing Record 46 of Set 3  | meulaboh
# Processing Record 47 of Set 3  | katsuura
# Processing Record 48 of Set 3  | waipawa
# Processing Record 49 of Set 3  | tulum
# Processing Record 50 of Set 3  | presidencia roque saenz pena
# Processing Record 2 of Set 4  | usoke
# Processing Record 3 of Set 4  | aklavik
# Processing Record 4 of Set 4  | beloha
# Processing Record 5 of Set 4  | mayo
# Processing Record 6 of Set 4  | faanui
# Processing Record 7 of Set 4  | yeltsovka
# Processing Record 8 of Set 4  | mackay
# Processing Record 9 of Set 4  | aasiaat
# Processing Record 10 of Set 4  | kerch
# Processing Record 11 of Set 4  | kazalinsk
# Processing Record 12 of Set 4  | pryazha
# Processing Record 13 of Set 4  | moengo
# Processing Record 14 of Set 4  | lumberton
# Processing Record 15 of Set 4  | mujiayingzi
# Processing Record 16 of Set 4  | camargo
# Processing Record 17 of Set 4  | usinsk
# Processing Record 18 of Set 4  | sentyabrskiy
# Processing Record 19 of Set 4  | lisala
# Processing Record 20 of Set 4  | farmington
# Processing Record 21 of Set 4  | mubende
# Processing Record 22 of Set 4  | togur
# Processing Record 23 of Set 4  | olafsvik
# Processing Record 24 of Set 4  | hay river
# Processing Record 25 of Set 4  | kutum
# Processing Record 26 of Set 4  | meridian
# Processing Record 27 of Set 4  | lorengau
# Processing Record 28 of Set 4  | nuuk
# Processing Record 29 of Set 4  | athabasca
# Processing Record 30 of Set 4  | castro
# Processing Record 31 of Set 4  | puerto escondido
# Processing Record 32 of Set 4  | hamilton
# Processing Record 33 of Set 4  | lakes entrance
# Processing Record 34 of Set 4  | gambela
# Processing Record 35 of Set 4  | northam
# Processing Record 36 of Set 4  | stoyba
# Processing Record 37 of Set 4  | faya
# Processing Record 38 of Set 4  | creel
# Processing Record 39 of Set 4  | bergerac
# Processing Record 40 of Set 4  | takhli
# Processing Record 41 of Set 4  | stanislav
# Processing Record 42 of Set 4  | mar del plata
# Processing Record 43 of Set 4  | alice springs
# Processing Record 44 of Set 4  | lipin bor
# Processing Record 45 of Set 4  | tura
# Processing Record 46 of Set 4  | astoria
# Processing Record 47 of Set 4  | mount darwin
# Processing Record 48 of Set 4  | albany
# Processing Record 49 of Set 4  | tautira
# Processing Record 50 of Set 4  | atambua
# Processing Record 2 of Set 5  | surin
# Processing Record 3 of Set 5  | severo-yeniseyskiy
# Processing Record 4 of Set 5  | zhenlai
# Processing Record 5 of Set 5  | orsha
# Processing Record 6 of Set 5  | atar
# Processing Record 7 of Set 5  | flinders
# Processing Record 8 of Set 5  | vardo
# Processing Record 9 of Set 5  | sawakin
# Processing Record 10 of Set 5  | the pas
# Processing Record 11 of Set 5  | santa isabel
# Processing Record 12 of Set 5  | korla
# Processing Record 13 of Set 5  | caravelas
# Processing Record 14 of Set 5  | alta floresta
# Processing Record 15 of Set 5  | barentsburg
# Processing Record 16 of Set 5  | waingapu
# Processing Record 17 of Set 5  | elliot lake
# Processing Record 18 of Set 5  | bandarbeyla
# Processing Record 19 of Set 5  | monaragala
# Processing Record 20 of Set 5  | verkhoyansk
# Processing Record 21 of Set 5  | belyy yar
# Processing Record 22 of Set 5  | gold coast
# Processing Record 23 of Set 5  | la palma
# Processing Record 24 of Set 5  | touros
# Processing Record 25 of Set 5  | victoria
# Processing Record 26 of Set 5  | taolanaro
# Processing Record 27 of Set 5  | esperance
# Processing Record 28 of Set 5  | ibotirama
# Processing Record 29 of Set 5  | thompson
# Processing Record 30 of Set 5  | alekseyevsk
# Processing Record 31 of Set 5  | rocha
# Processing Record 32 of Set 5  | umm lajj
# Processing Record 33 of Set 5  | saint-philippe
# Processing Record 34 of Set 5  | ancud
# Processing Record 35 of Set 5  | partizansk
# Processing Record 36 of Set 5  | anori
# Processing Record 37 of Set 5  | rawannawi
# Processing Record 38 of Set 5  | kaspiyskiy
# Processing Record 39 of Set 5  | bud
# Processing Record 40 of Set 5  | jiaocheng
# Processing Record 41 of Set 5  | mingaora
# Processing Record 42 of Set 5  | kuloy
# Processing Record 43 of Set 5  | kpandae
# Processing Record 44 of Set 5  | qaanaaq
# Processing Record 45 of Set 5  | illoqqortoormiut
# Processing Record 46 of Set 5  | broome
# Processing Record 47 of Set 5  | plettenberg bay
# Processing Record 48 of Set 5  | la ronge
# Processing Record 49 of Set 5  | nanortalik
# Processing Record 50 of Set 5  | sturgeon bay
# Processing Record 2 of Set 6  | clyde river
# Processing Record 3 of Set 6  | attawapiskat
# Processing Record 4 of Set 6  | champerico
# Processing Record 5 of Set 6  | karaul
# Processing Record 6 of Set 6  | visegrad
# Processing Record 7 of Set 6  | changping
# Processing Record 8 of Set 6  | solnechnyy
# Processing Record 9 of Set 6  | lata
# Processing Record 10 of Set 6  | lebu
# Processing Record 11 of Set 6  | karpathos
# Processing Record 12 of Set 6  | bambanglipuro
# Processing Record 13 of Set 6  | alofi
# Processing Record 14 of Set 6  | eureka
# Processing Record 15 of Set 6  | hermanus
# Processing Record 16 of Set 6  | harrison
# Processing Record 17 of Set 6  | chuy
# Processing Record 18 of Set 6  | manturovo
# Processing Record 19 of Set 6  | fare
# Processing Record 20 of Set 6  | delta del tigre
# Processing Record 21 of Set 6  | wuda
# Processing Record 22 of Set 6  | pochutla
# Processing Record 23 of Set 6  | sitka
# Processing Record 24 of Set 6  | bajo baudo
# Processing Record 25 of Set 6  | makakilo city
# Processing Record 26 of Set 6  | lufilufi
# Processing Record 27 of Set 6  | peniche
# Processing Record 28 of Set 6  | pangnirtung
# Processing Record 29 of Set 6  | poum
# Processing Record 30 of Set 6  | sembakung
# Processing Record 31 of Set 6  | chulumani
# Processing Record 32 of Set 6  | souillac
# Processing Record 33 of Set 6  | taoudenni
# Processing Record 34 of Set 6  | minsk
# Processing Record 35 of Set 6  | santana do livramento
# Processing Record 36 of Set 6  | ewa beach
# Processing Record 37 of Set 6  | te anau
# Processing Record 38 of Set 6  | ormond beach
# Processing Record 39 of Set 6  | brae
# Processing Record 40 of Set 6  | akmene
# Processing Record 41 of Set 6  | ebano
# Processing Record 42 of Set 6  | tigil
# Processing Record 43 of Set 6  | vankleek hill
# Processing Record 44 of Set 6  | awbari
# Processing Record 45 of Set 6  | saint george
# Processing Record 46 of Set 6  | andros town
# Processing Record 47 of Set 6  | mrirt
# Processing Record 48 of Set 6  | hueytamalco
# Processing Record 49 of Set 6  | deputatskiy
# Processing Record 50 of Set 6  | inhambane
# Processing Record 2 of Set 7  | san vicente
# Processing Record 3 of Set 7  | margate
# Processing Record 4 of Set 7  | umtata
# Processing Record 5 of Set 7  | drezna
# Processing Record 6 of Set 7  | pithoragarh
# Processing Record 7 of Set 7  | beringovskiy
# Processing Record 8 of Set 7  | tazovskiy
# Processing Record 9 of Set 7  | tsihombe
# Processing Record 10 of Set 7  | wakkanai
# Processing Record 11 of Set 7  | ardalstangen
# Processing Record 12 of Set 7  | kadyy
# Processing Record 13 of Set 7  | nome
# Processing Record 14 of Set 7  | husavik
# Processing Record 15 of Set 7  | severo-kurilsk
# Processing Record 16 of Set 7  | karkaralinsk
# Processing Record 17 of Set 7  | asau
# Processing Record 18 of Set 7  | ribas do rio pardo
# Processing Record 19 of Set 7  | millerovo
# Processing Record 20 of Set 7  | carutapera
# Processing Record 21 of Set 7  | grand river south east
# Processing Record 22 of Set 7  | tasiilaq
# Processing Record 23 of Set 7  | taltal
# Processing Record 24 of Set 7  | santa isabel do rio negro
# Processing Record 25 of Set 7  | balkanabat
# Processing Record 26 of Set 7  | college
# Processing Record 27 of Set 7  | sorvag
# Processing Record 28 of Set 7  | bizhbulyak
# Processing Record 29 of Set 7  | asfi
# Processing Record 30 of Set 7  | phan thiet
# Processing Record 31 of Set 7  | chimbote
# Processing Record 32 of Set 7  | kokopo
# Processing Record 33 of Set 7  | la rioja
# Processing Record 34 of Set 7  | ambilobe
# Processing Record 35 of Set 7  | yomitan
# Processing Record 36 of Set 7  | manaure
# Processing Record 37 of Set 7  | awjilah
# Processing Record 38 of Set 7  | san patricio
# Processing Record 39 of Set 7  | wajid
# Processing Record 40 of Set 7  | durango
# Processing Record 41 of Set 7  | komatipoort
# Processing Record 42 of Set 7  | republic
# Processing Record 43 of Set 7  | atherton
# Processing Record 44 of Set 7  | betioky
# Processing Record 45 of Set 7  | bluff
# Processing Record 46 of Set 7  | lebedinyy
# Processing Record 47 of Set 7  | dinan
# Processing Record 48 of Set 7  | ifanadiana
# Processing Record 49 of Set 7  | jaboticabal
# Processing Record 50 of Set 7  | olinda
# Processing Record 2 of Set 8  | halden
# Processing Record 3 of Set 8  | dikson
# Processing Record 4 of Set 8  | russell
# Processing Record 5 of Set 8  | jalu
# Processing Record 6 of Set 8  | adelaide
# Processing Record 7 of Set 8  | assela
# Processing Record 8 of Set 8  | montepuez
# Processing Record 9 of Set 8  | shimoda
# Processing Record 10 of Set 8  | ellisras
# Processing Record 11 of Set 8  | tres arroyos
# Processing Record 12 of Set 8  | roald
# Processing Record 13 of Set 8  | srednekolymsk
# Processing Record 14 of Set 8  | vaini
# Processing Record 15 of Set 8  | coahuayana
# Processing Record 16 of Set 8  | fort-shevchenko
# Processing Record 17 of Set 8  | mataura
# Processing Record 18 of Set 8  | kununurra
# Processing Record 19 of Set 8  | dunkwa
# Processing Record 20 of Set 8  | bethel
# Processing Record 21 of Set 8  | sakakah
# Processing Record 22 of Set 8  | boulder city
# Processing Record 23 of Set 8  | mitsamiouli
# Processing Record 24 of Set 8  | guarda
# Processing Record 25 of Set 8  | maneadero
# Processing Record 26 of Set 8  | cockburn town
# Processing Record 27 of Set 8  | tongchuan
# Processing Record 28 of Set 8  | amderma
# Processing Record 29 of Set 8  | sechura
# Processing Record 30 of Set 8  | bilecik
# Processing Record 31 of Set 8  | youkounkoun
# Processing Record 32 of Set 8  | longyearbyen
# Processing Record 33 of Set 8  | erenhot
# Processing Record 34 of Set 8  | marawi
# Processing Record 35 of Set 8  | boditi
# Processing Record 36 of Set 8  | klaksvik
# Processing Record 37 of Set 8  | leningradskiy
# Processing Record 38 of Set 8  | mananara
# Processing Record 39 of Set 8  | hasaki
# Processing Record 40 of Set 8  | nizhniy odes
# Processing Record 41 of Set 8  | pimentel
# Processing Record 42 of Set 8  | khatanga
# Processing Record 43 of Set 8  | port alfred
# Processing Record 44 of Set 8  | sao sepe
# Processing Record 45 of Set 8  | louisbourg
# Processing Record 46 of Set 8  | ilulissat
# Processing Record 47 of Set 8  | umm durman
# Processing Record 48 of Set 8  | punta arenas
# Processing Record 49 of Set 8  | vila velha
# Processing Record 50 of Set 8  | inuvik
# Processing Record 2 of Set 9  | mogadishu
# Processing Record 3 of Set 9  | miri
# Processing Record 4 of Set 9  | oistins
# Processing Record 5 of Set 9  | vaitupu
# Processing Record 6 of Set 9  | kieta
# Processing Record 7 of Set 9  | khairpur nathan shah
# Processing Record 8 of Set 9  | mahebourg
# Processing Record 9 of Set 9  | ormara
# Processing Record 10 of Set 9  | doha
# Processing Record 11 of Set 9  | san miguel
# Processing Record 12 of Set 9  | barawe
# Processing Record 13 of Set 9  | carnarvon
# Processing Record 14 of Set 9  | gladstone
# Processing Record 15 of Set 9  | acarau
# Processing Record 16 of Set 9  | sarankhola
# Processing Record 17 of Set 9  | saskylakh
# Processing Record 18 of Set 9  | charters towers
# Processing Record 19 of Set 9  | port-gentil
# Processing Record 20 of Set 9  | ahome
# Processing Record 21 of Set 9  | santa marta
# Processing Record 22 of Set 9  | slave lake
# Processing Record 23 of Set 9  | garowe
# Processing Record 24 of Set 9  | ulagan
# Processing Record 25 of Set 9  | vancouver
# Processing Record 26 of Set 9  | la sarre
# Processing Record 27 of Set 9  | half moon bay
# Processing Record 28 of Set 9  | hare bay
# Processing Record 29 of Set 9  | high level
# Processing Record 30 of Set 9  | vestmanna
# Processing Record 31 of Set 9  | vanavara
# Processing Record 32 of Set 9  | richards bay
# Processing Record 33 of Set 9  | ostrovnoy
# Processing Record 34 of Set 9  | krasnoselkup
# Processing Record 35 of Set 9  | palmer
# Processing Record 36 of Set 9  | balakhta
# Processing Record 37 of Set 9  | saint-augustin
# Processing Record 38 of Set 9  | kawhia
# Processing Record 39 of Set 9  | pangody
# Processing Record 40 of Set 9  | puerto ayora
# Processing Record 41 of Set 9  | maragogi
# Processing Record 42 of Set 9  | karratha
# Processing Record 43 of Set 9  | kurchum
# Processing Record 44 of Set 9  | aban
# Processing Record 45 of Set 9  | rikitea
# Processing Record 46 of Set 9  | imuris
# Processing Record 47 of Set 9  | reshetnikovo
# Processing Record 48 of Set 9  | sri aman
# Processing Record 49 of Set 9  | vrede
# Processing Record 50 of Set 9  | sao joao da barra
# Processing Record 2 of Set 10  | hilo
# Processing Record 3 of Set 10  | port hardy
# Processing Record 4 of Set 10  | barabinsk
# Processing Record 5 of Set 10  | soyo
# Processing Record 6 of Set 10  | lavrentiya
# Processing Record 7 of Set 10  | el paso
# Processing Record 8 of Set 10  | marcona
# Processing Record 9 of Set 10  | ramhormoz
# Processing Record 10 of Set 10  | phuntsholing
# Processing Record 11 of Set 10  | fort nelson
# Processing Record 12 of Set 10  | cabog
# Processing Record 13 of Set 10  | ust-nera
# Processing Record 14 of Set 10  | mayor pablo lagerenza
# Processing Record 15 of Set 10  | olden
# Processing Record 16 of Set 10  | moroni
# Processing Record 17 of Set 10  | yumen
# Processing Record 18 of Set 10  | mahanoro
# Processing Record 19 of Set 10  | macara
# Processing Record 20 of Set 10  | upernavik
# Processing Record 21 of Set 10  | mancio lima
# Processing Record 22 of Set 10  | kingisepp
# Processing Record 23 of Set 10  | arlit
# Processing Record 24 of Set 10  | itamaraca
# Processing Record 25 of Set 10  | matamoros
# Processing Record 26 of Set 10  | carauari
# Processing Record 27 of Set 10  | peleduy
# Processing Record 28 of Set 10  | cape town
# Processing Record 29 of Set 10  | cayenne
# Processing Record 30 of Set 10  | churapcha
# Processing Record 31 of Set 10  | ishigaki
# Processing Record 32 of Set 10  | wellington
# Processing Record 33 of Set 10  | maniwaki
# Processing Record 34 of Set 10  | sibolga
# Processing Record 35 of Set 10  | galle
# Processing Record 36 of Set 10  | qandahar
# Processing Record 37 of Set 10  | frankfort
# Processing Record 38 of Set 10  | imbituba
# Processing Record 39 of Set 10  | shingu
# Processing Record 40 of Set 10  | laiagam
# Processing Record 41 of Set 10  | maua
# Processing Record 42 of Set 10  | espanola
# Processing Record 43 of Set 10  | henties bay
# Processing Record 44 of Set 10  | camacha
# Processing Record 45 of Set 10  | talaya
# Processing Record 46 of Set 10  | hithadhoo
# Processing Record 47 of Set 10  | tak
# Processing Record 48 of Set 10  | ribeira grande
# Processing Record 49 of Set 10  | aktau
# Processing Record 50 of Set 10  | hurghada
# Processing Record 2 of Set 11  | bereznik
# Processing Record 3 of Set 11  | santiago del estero
# Processing Record 4 of Set 11  | madang
# Processing Record 5 of Set 11  | puerto leguizamo
# Processing Record 6 of Set 11  | rogun
# Processing Record 7 of Set 11  | karla
# Processing Record 8 of Set 11  | omsukchan
# Processing Record 9 of Set 11  | high rock
# Processing Record 10 of Set 11  | san juan
# Processing Record 11 of Set 11  | tafalla
# Processing Record 12 of Set 11  | maarianhamina
# Processing Record 13 of Set 11  | burnie
# Processing Record 14 of Set 11  | whangamata
# Processing Record 15 of Set 11  | nador
# Processing Record 16 of Set 11  | acapulco
# Processing Record 17 of Set 11  | isangel
# Processing Record 18 of Set 11  | pacific grove
# Processing Record 19 of Set 11  | ville-marie
# Processing Record 20 of Set 11  | ximei
# Processing Record 21 of Set 11  | warqla
# Processing Record 22 of Set 11  | aykhal
# Processing Record 23 of Set 11  | ponta delgada
# Processing Record 24 of Set 11  | satitoa
# Processing Record 25 of Set 11  | sisimiut
# Processing Record 26 of Set 11  | deder
# Processing Record 27 of Set 11  | bushehr
# Processing Record 28 of Set 11  | khanpur
# Processing Record 29 of Set 11  | barrow
# Processing Record 30 of Set 11  | manokwari
# Processing Record 31 of Set 11  | morris
# Processing Record 32 of Set 11  | luwuk
# Processing Record 33 of Set 11  | padang
# Processing Record 34 of Set 11  | banjar
# Processing Record 35 of Set 11  | avarua
# Processing Record 36 of Set 11  | palabuhanratu
# Processing Record 37 of Set 11  | pevek
# Processing Record 38 of Set 11  | constitucion
# Processing Record 39 of Set 11  | najran
# Processing Record 40 of Set 11  | salamiyah
# Processing Record 41 of Set 11  | laguna
# Processing Record 42 of Set 11  | kalmunai
# Processing Record 43 of Set 11  | surt
# Processing Record 44 of Set 11  | kargasok
# Processing Record 45 of Set 11  | delijan
# Processing Record 46 of Set 11  | pasighat
# Processing Record 47 of Set 11  | ghazipur
# Processing Record 48 of Set 11  | zolotinka
# Processing Record 49 of Set 11  | victor harbor
# Processing Record 50 of Set 11  | yeniseysk
# Processing Record 2 of Set 12  | santa barbara
# Processing Record 3 of Set 12  | moosomin
# Processing Record 4 of Set 12  | kuche
# Processing Record 5 of Set 12  | luchegorsk
# Processing Record 6 of Set 12  | atuona
# Processing Record 7 of Set 12  | abu samrah
# Processing Record 8 of Set 12  | arkhara
# Processing Record 9 of Set 12  | roswell
# Processing Record 10 of Set 12  | darlawn
# Processing Record 11 of Set 12  | cherskiy
# Processing Record 12 of Set 12  | tateyama
# Processing Record 13 of Set 12  | cabo san lucas
# Processing Record 14 of Set 12  | moron
# Processing Record 15 of Set 12  | along
# Processing Record 16 of Set 12  | sinnamary
# Processing Record 17 of Set 12  | skelleftea
# Processing Record 18 of Set 12  | kalagarh
# Processing Record 19 of Set 12  | norman wells
# Processing Record 20 of Set 12  | vila
# Processing Record 21 of Set 12  | promyshlennyy
# Processing Record 22 of Set 12  | ulladulla
# Processing Record 23 of Set 12  | haines junction
# Processing Record 24 of Set 12  | giyani
# Processing Record 25 of Set 12  | kavaratti
# Processing Record 26 of Set 12  | san bartolome de tirajana
# Processing Record 27 of Set 12  | bambous virieux
# Processing Record 28 of Set 12  | hereford
# Processing Record 29 of Set 12  | ngunguru
# Processing Record 30 of Set 12  | provideniya
# Processing Record 31 of Set 12  | nizhneyansk
# Processing Record 32 of Set 12  | ostrowiec swietokrzyski
# Processing Record 33 of Set 12  | bredasdorp
# Processing Record 34 of Set 12  | aswan
# Processing Record 35 of Set 12  | urumqi
# Processing Record 36 of Set 12  | massillon
# Processing Record 37 of Set 12  | batagay
# Processing Record 38 of Set 12  | toktogul
# Processing Record 39 of Set 12  | moussoro
# Processing Record 40 of Set 12  | beira
# Processing Record 41 of Set 12  | chitral
# Processing Record 42 of Set 12  | touba
# Processing Record 43 of Set 12  | halen
# Processing Record 44 of Set 12  | belaya gora
# Processing Record 45 of Set 12  | sompeta
# Processing Record 46 of Set 12  | vila franca do campo
# Processing Record 47 of Set 12  | kudchi
# Processing Record 48 of Set 12  | shache
# Processing Record 49 of Set 12  | luderitz
# Processing Record 50 of Set 12  | el faiyum
# Processing Record 2 of Set 13  | alwar tirunagari
# Processing Record 3 of Set 13  | nouadhibou
# Processing Record 4 of Set 13  | kalabo
# Processing Record 5 of Set 13  | eau claire
# Processing Record 6 of Set 13  | sangar
# Processing Record 7 of Set 13  | ballina
# Processing Record 8 of Set 13  | codrington
# Processing Record 9 of Set 13  | seoul
# Processing Record 10 of Set 13  | sambava
# Processing Record 11 of Set 13  | cabedelo
# Processing Record 12 of Set 13  | castelo branco
# Processing Record 13 of Set 13  | srandakan
# Processing Record 14 of Set 13  | port hawkesbury
# Processing Record 15 of Set 13  | torbay
# Processing Record 16 of Set 13  | inyonga
# Processing Record 17 of Set 13  | areosa
# Processing Record 18 of Set 13  | coihaique
# Processing Record 19 of Set 13  | luz
# Processing Record 20 of Set 13  | ust-kuyga
# Processing Record 21 of Set 13  | villa vazquez
# Processing Record 22 of Set 13  | moose factory
# Processing Record 23 of Set 13  | kamenskoye
# Processing Record 24 of Set 13  | byron bay
# Processing Record 25 of Set 13  | komsomolskiy
# Processing Record 26 of Set 13  | vanimo
# Processing Record 27 of Set 13  | nikolskoye
# Processing Record 28 of Set 13  | bengkulu
# Processing Record 29 of Set 13  | mana
# Processing Record 30 of Set 13  | shunyi
# Processing Record 31 of Set 13  | flin flon
# Processing Record 32 of Set 13  | leh
# Processing Record 33 of Set 13  | belushya guba
# Processing Record 34 of Set 13  | necochea
# Processing Record 35 of Set 13  | kruisfontein
# Processing Record 36 of Set 13  | kaoma
# Processing Record 37 of Set 13  | denpasar
# Processing Record 38 of Set 13  | chama
# Processing Record 39 of Set 13  | hobyo
# Processing Record 40 of Set 13  | yerbogachen
# Processing Record 41 of Set 13  | mangrol
# Processing Record 42 of Set 13  | bathsheba
# Processing Record 43 of Set 13  | la asuncion
# Processing Record 44 of Set 13  | sucre
# Processing Record 45 of Set 13  | ferme-neuve
# Processing Record 46 of Set 13  | rawson
# Processing Record 47 of Set 13  | viytivka
# Processing Record 48 of Set 13  | pisco
# Processing Record 49 of Set 13  | gornorechenskiy
# Processing Record 50 of Set 13  | qasigiannguit
# Processing Record 2 of Set 14  | tiznit
# Processing Record 3 of Set 14  | busselton
# Processing Record 4 of Set 14  | lagoa
# Processing Record 5 of Set 14  | selma
# Processing Record 6 of Set 14  | sivas
# Processing Record 7 of Set 14  | auki
# Processing Record 8 of Set 14  | beamsville
# Processing Record 9 of Set 14  | yatou
# Processing Record 10 of Set 14  | puerto palomas
# Processing Record 11 of Set 14  | hyeres
# Processing Record 12 of Set 14  | tyrma
# Processing Record 13 of Set 14  | buala
# Processing Record 14 of Set 14  | sayyan
# Processing Record 15 of Set 14  | paysandu
# Processing Record 16 of Set 14  | quelimane
# Processing Record 17 of Set 14  | cairns
# Processing Record 18 of Set 14  | meyungs
# Processing Record 19 of Set 14  | tuatapere
# Processing Record 20 of Set 14  | lompoc
# Processing Record 21 of Set 14  | viedma
# Processing Record 22 of Set 14  | naron
# Processing Record 23 of Set 14  | lazaro cardenas
# Processing Record 24 of Set 14  | smolenka
# Processing Record 25 of Set 14  | joensuu
# Processing Record 26 of Set 14  | ahipara
# Processing Record 27 of Set 14  | bjala
# Processing Record 28 of Set 14  | mago
# Processing Record 29 of Set 14  | great yarmouth
# Processing Record 30 of Set 14  | rabo de peixe
# Processing Record 31 of Set 14  | xichang
# Processing Record 32 of Set 14  | vilyuysk
# Processing Record 33 of Set 14  | omboue
# Processing Record 34 of Set 14  | new norfolk
# Processing Record 35 of Set 14  | alingsas
# Processing Record 36 of Set 14  | parana
# Processing Record 37 of Set 14  | matadi
# Processing Record 38 of Set 14  | iqaluit
# Processing Record 39 of Set 14  | sampit
# Processing Record 40 of Set 14  | strezhevoy
# Processing Record 41 of Set 14  | mitu
# Processing Record 42 of Set 14  | sao gabriel da cachoeira
# Processing Record 43 of Set 14  | oktyabrskiy
# Processing Record 44 of Set 14  | sao filipe
# Processing Record 45 of Set 14  | ust-tsilma
# Processing Record 46 of Set 14  | taksimo
# Processing Record 47 of Set 14  | wanning
# Processing Record 48 of Set 14  | cairo
# Processing Record 49 of Set 14  | dillon
# Processing Record 50 of Set 14  | borgarnes
# Processing Record 2 of Set 15  | benghazi
# Processing Record 3 of Set 15  | guaruja
# Processing Record 4 of Set 15  | dogondoutchi
# Processing Record 5 of Set 15  | khandyga
# Processing Record 6 of Set 15  | abu dhabi
# Processing Record 7 of Set 15  | kon tum
# Processing Record 8 of Set 15  | sheridan
# Processing Record 9 of Set 15  | kahului
# Processing Record 10 of Set 15  | tromso
# Processing Record 11 of Set 15  | sinjai
# Processing Record 12 of Set 15  | dattapur
# Processing Record 13 of Set 15  | qaqortoq
# Processing Record 14 of Set 15  | labuhan
# Processing Record 15 of Set 15  | rungata
# Processing Record 16 of Set 15  | tuktoyaktuk
# Processing Record 17 of Set 15  | kristiinankaupunki
# Processing Record 18 of Set 15  | buren
# Processing Record 19 of Set 15  | salalah
# Processing Record 20 of Set 15  | hualmay
# Processing Record 21 of Set 15  | hailar
# Processing Record 22 of Set 15  | kemijarvi
# Processing Record 23 of Set 15  | kenai
# Processing Record 24 of Set 15  | asekeyevo
# Processing Record 25 of Set 15  | madhupur
# Processing Record 26 of Set 15  | fevralsk
# Processing Record 27 of Set 15  | semey
# Processing Record 28 of Set 15  | razdolinsk
# Processing Record 29 of Set 15  | grindavik
# Processing Record 30 of Set 15  | belmonte
# Processing Record 31 of Set 15  | xining
# Processing Record 32 of Set 15  | iranshahr
# Processing Record 33 of Set 15  | kamenka
# Processing Record 34 of Set 15  | gushikawa
# Processing Record 35 of Set 15  | ushuaia
# Processing Record 36 of Set 15  | cap-aux-meules
# Processing Record 37 of Set 15  | ketchikan
# Processing Record 38 of Set 15  | nishihara
# Processing Record 39 of Set 15  | makungu
# Processing Record 40 of Set 15  | consuegra
# Processing Record 41 of Set 15  | kavieng
# Processing Record 42 of Set 15  | port elizabeth
# Processing Record 43 of Set 15  | gulshat
# Processing Record 44 of Set 15  | wulanhaote
# Processing Record 45 of Set 15  | batticaloa
# Processing Record 46 of Set 15  | ponta do sol
# Processing Record 47 of Set 15  | limbang
# Processing Record 48 of Set 15  | chokurdakh
# Processing Record 49 of Set 15  | chulym
# Processing Record 50 of Set 15  | skjervoy
# Processing Record 2 of Set 16  | butaritari
# Processing Record 3 of Set 16  | edd
# Processing Record 4 of Set 16  | jamestown
# Processing Record 5 of Set 16  | halalo
# Processing Record 6 of Set 16  | launceston
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     wloszczowa      PL  50.85   19.97     35.65        57           0
# 1     hambantota      LK   6.12   81.12     75.54       100          20
# 2        kirovsk      UA  48.64   38.64     25.97        95          35
# 3    boshnyakovo      RU  49.63  142.17     20.28        78         100
# 4  mount gambier      AU -37.83  140.77     66.11        77         100
#
#    Wind Speed Current Description
# 0        6.22           clear sky
# 1        1.14          few clouds
# 2        4.65    scattered clouds
# 3        6.22     overcast clouds
# 4        6.91     overcast clouds

# %%
columns_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
df = df[columns_order]
df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       wloszczowa      PL  50.85   19.97     35.65        57           0
# 1       hambantota      LK   6.12   81.12     75.54       100          20
# 2          kirovsk      UA  48.64   38.64     25.97        95          35
# 3      boshnyakovo      RU  49.63  142.17     20.28        78         100
# 4    mount gambier      AU -37.83  140.77     66.11        77         100
# ..             ...     ...    ...     ...       ...       ...         ...
# 681       skjervoy      NO  70.03   20.97     41.61        63          94
# 682     butaritari      KI   3.07  172.79     81.21        78          37
# 683            edd      ER  13.93   41.69     83.64        49          79
# 684      jamestown      US  42.10  -79.24     42.03        48           0
# 685     launceston      AU -41.45  147.17     69.44        66         100
#
#      Wind Speed Current Description
# 0          6.22           clear sky
# 1          1.14          few clouds
# 2          4.65    scattered clouds
# 3          6.22     overcast clouds
# 4          6.91     overcast clouds
# ..          ...                 ...
# 681       14.29     overcast clouds
# 682       19.77          light rain
# 683        3.76       broken clouds
# 684       11.50           clear sky
# 685        6.91     overcast clouds
#
# [686 rows x 9 columns]

# %% [markdown]
# ### Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Export 
output_file = "WeatherPy_Database.csv"
df.to_csv(output_file,index_label='City_ID')
